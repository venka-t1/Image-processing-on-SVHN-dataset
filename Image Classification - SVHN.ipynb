# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (File -> Download as -> PDF via LaTeX). You should then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
from scipy.io import loadmat
import pandas as pd
import numpy as np

# %% [markdown]
# ![SVHN overview image](data/svhn_examples.jpg)
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an  image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to load the dataset

train = loadmat('data/train_32x32.mat')
test = loadmat('data/test_32x32.mat')

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
from sklearn.preprocessing import OneHotEncoder

x_train = np.transpose(train['X'],(3,0,1,2))/255
x_test =  np.transpose(test['X'],(3,0,1,2))/255

encoder = OneHotEncoder(sparse=False)

y_train = encoder.fit_transform(train['y']%10)
y_test = encoder.fit_transform(test['y']%10)

# %%
import random
import matplotlib.pyplot as plt

def random_image(x,y):
    no_sam = x.shape[0]
    index = random.sample(range(0,no_sam+1),15)
    fig , axis = plt.subplots(nrows = 3,ncols = 4, figsize =(12,12))
    
    for i, ax in zip(index,axis.flatten()):
        if(x[i].shape==(32,32,3)):
            ax.imshow(x[i])
        else:
            ax.imshow(x[i,...,0],cmap='gray')
        ax.set_xlabel("label:"+ str(np.argmax(y[i])))

# %%
random_image(x_train,y_train)

# %%
def reshape_img(img):
    return np.dot(img,[0.2989,0.5870,0.1140])[...,np.newaxis]
x_train_gray=reshape_img(x_train).astype(np.float32)
x_test_gray=reshape_img(x_test).astype(np.float32)

# %%
random_image(x_train_gray,y_train)

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau

# %%
def mlp_model(input_shape):
    return Sequential([
        Flatten(name='flatten_1', input_shape = input_shape),
        Dense(128,activation = 'relu'),
        Dense(128,activation = 'relu'),
        Dense(128,activation = 'relu'),
        Dense(64,activation = 'relu'),
        Dense(10,activation = 'softmax')
        ])
def test_result(model):
    test_loss,test_acc = model.evaluate(x_test_gray,y_test,verbose=False)
    print(f"Test Accuracy: {test_acc}")
    print(f"Test Loss: {test_loss}")

def plot_model(history):
    fig, axis = plt.subplots(nrows = 2,ncols=1,figsize=(10,10))
    axis[0].plot(history['val_loss'],label='Validation loss',color = 'green')
    axis[0].plot(history['loss'],label='training loss',color = 'red')
    axis[0].set_ylabel('val_loss')
    axis[0].set_xlabel('epoch')
    axis[0].legend()
    axis[1].plot(history['val_accuracy'],label='Validation accuracy',color = 'green')
    axis[1].plot(history['accuracy'],label='training accuracy',color = 'red')
    axis[1].set_ylabel('val_accuracy')
    axis[1].set_xlabel('epoch')
    axis[1].legend()

# %%
shape= x_train_gray[0].shape
mmodel = mlp_model(shape)
mmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 173,130
# Trainable params: 173,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
def callback(model_type):
    early_stop = EarlyStopping(monitor='loss',patience = 10, verbose = 1)
    plateau = ReduceLROnPlateau(monitor = 'loss',patience = 10, factor=0.2)
    path = 'model-'+model_type+'/checkpoint-epoch: {epoch:02d}'
    check_path = ModelCheckpoint(filepath = path,monitor = 'val_accuracy',save_weights_only=True,save_best_only =True,verbose = 1)
    return early_stop,plateau,check_path

# %%
mmodel.compile(optimizer='sgd',loss='categorical_crossentropy',metrics = ['accuracy'])

# %%
early_stop,plateau,check_path = callback('mlp')
history = mmodel.fit(x_train_gray,y_train,epochs=30,validation_split=0.2,callbacks = [early_stop,plateau,check_path])
# Out:
# Train on 58605 samples, validate on 14652 samples
# Epoch 1/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 2.1981 - accuracy: 0.2059
# Epoch 00001: val_accuracy improved from -inf to 0.22679, saving model to model-mlp/checkpoint-epoch: 01
# 58605/58605 [==============================] - 27s 469us/sample - loss: 2.1979 - accuracy: 0.2060 - val_loss: 2.1321 - val_accuracy: 0.2268
# Epoch 2/30
# 58528/58605 [============================>.] - ETA: 0s - loss: 1.8359 - accuracy: 0.3675
# Epoch 00002: val_accuracy improved from 0.22679 to 0.38384, saving model to model-mlp/checkpoint-epoch: 02
# 58605/58605 [==============================] - 26s 442us/sample - loss: 1.8358 - accuracy: 0.3676 - val_loss: 1.7968 - val_accuracy: 0.3838
# Epoch 3/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 1.4605 - accuracy: 0.5173
# Epoch 00003: val_accuracy improved from 0.38384 to 0.47755, saving model to model-mlp/checkpoint-epoch: 03
# 58605/58605 [==============================] - 25s 435us/sample - loss: 1.4600 - accuracy: 0.5175 - val_loss: 1.7268 - val_accuracy: 0.4775
# Epoch 4/30
# 58592/58605 [============================>.] - ETA: 0s - loss: 1.2629 - accuracy: 0.5971
# Epoch 00004: val_accuracy improved from 0.47755 to 0.60442, saving model to model-mlp/checkpoint-epoch: 04
# 58605/58605 [==============================] - 26s 448us/sample - loss: 1.2628 - accuracy: 0.5972 - val_loss: 1.2281 - val_accuracy: 0.6044
# Epoch 5/30
# 58592/58605 [============================>.] - ETA: 0s - loss: 1.1399 - accuracy: 0.6451
# Epoch 00005: val_accuracy improved from 0.60442 to 0.63875, saving model to model-mlp/checkpoint-epoch: 05
# 58605/58605 [==============================] - 26s 443us/sample - loss: 1.1399 - accuracy: 0.6451 - val_loss: 1.1670 - val_accuracy: 0.6388
# Epoch 6/30
# 58496/58605 [============================>.] - ETA: 0s - loss: 1.0569 - accuracy: 0.6734
# Epoch 00006: val_accuracy improved from 0.63875 to 0.66400, saving model to model-mlp/checkpoint-epoch: 06
# 58605/58605 [==============================] - 26s 444us/sample - loss: 1.0569 - accuracy: 0.6733 - val_loss: 1.0813 - val_accuracy: 0.6640
# Epoch 7/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.9973 - accuracy: 0.6920
# Epoch 00007: val_accuracy did not improve from 0.66400
# 58605/58605 [==============================] - 26s 445us/sample - loss: 0.9972 - accuracy: 0.6919 - val_loss: 1.2823 - val_accuracy: 0.6033
# Epoch 8/30
# 58464/58605 [============================>.] - ETA: 0s - loss: 0.9493 - accuracy: 0.7073
# Epoch 00008: val_accuracy improved from 0.66400 to 0.69008, saving model to model-mlp/checkpoint-epoch: 08
# 58605/58605 [==============================] - 27s 459us/sample - loss: 0.9488 - accuracy: 0.7074 - val_loss: 0.9983 - val_accuracy: 0.6901
# Epoch 9/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 0.9075 - accuracy: 0.7205
# Epoch 00009: val_accuracy did not improve from 0.69008
# 58605/58605 [==============================] - 27s 457us/sample - loss: 0.9073 - accuracy: 0.7206 - val_loss: 1.2100 - val_accuracy: 0.6217
# Epoch 10/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 0.8678 - accuracy: 0.7318 ETA: 1s - loss: 0.8695  - ETA: 0s - loss: 0.8683 - accuracy: 0.
# Epoch 00010: val_accuracy did not improve from 0.69008
# 58605/58605 [==============================] - 26s 447us/sample - loss: 0.8680 - accuracy: 0.7318 - val_loss: 1.1487 - val_accuracy: 0.6526
# Epoch 11/30
# 58496/58605 [============================>.] - ETA: 0s - loss: 0.8387 - accuracy: 0.7396
# Epoch 00011: val_accuracy did not improve from 0.69008
# 58605/58605 [==============================] - 26s 449us/sample - loss: 0.8386 - accuracy: 0.7396 - val_loss: 1.1561 - val_accuracy: 0.6428
# Epoch 12/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.8087 - accuracy: 0.7507
# Epoch 00012: val_accuracy improved from 0.69008 to 0.72290, saving model to model-mlp/checkpoint-epoch: 12
# 58605/58605 [==============================] - 26s 442us/sample - loss: 0.8082 - accuracy: 0.7509 - val_loss: 0.8887 - val_accuracy: 0.7229
# Epoch 13/30
# 58432/58605 [============================>.] - ETA: 0s - loss: 0.7839 - accuracy: 0.7571
# Epoch 00013: val_accuracy did not improve from 0.72290
# 58605/58605 [==============================] - 26s 440us/sample - loss: 0.7836 - accuracy: 0.7572 - val_loss: 1.0981 - val_accuracy: 0.6556
# Epoch 14/30
# 58368/58605 [============================>.] - ETA: 0s - loss: 0.7582 - accuracy: 0.7677
# Epoch 00014: val_accuracy improved from 0.72290 to 0.76085, saving model to model-mlp/checkpoint-epoch: 14
# 58605/58605 [==============================] - 26s 451us/sample - loss: 0.7579 - accuracy: 0.7678 - val_loss: 0.7767 - val_accuracy: 0.7609
# Epoch 15/30
# 58496/58605 [============================>.] - ETA: 0s - loss: 0.7375 - accuracy: 0.7707
# Epoch 00015: val_accuracy did not improve from 0.76085
# 58605/58605 [==============================] - 26s 448us/sample - loss: 0.7377 - accuracy: 0.7706 - val_loss: 0.8985 - val_accuracy: 0.7170
# Epoch 16/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.7197 - accuracy: 0.7776
# Epoch 00016: val_accuracy did not improve from 0.76085
# 58605/58605 [==============================] - 27s 454us/sample - loss: 0.7196 - accuracy: 0.7777 - val_loss: 0.7901 - val_accuracy: 0.7539
# Epoch 17/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 0.6968 - accuracy: 0.7850
# Epoch 00017: val_accuracy did not improve from 0.76085
# 58605/58605 [==============================] - 26s 452us/sample - loss: 0.6970 - accuracy: 0.7850 - val_loss: 0.7666 - val_accuracy: 0.7602
# Epoch 18/30
# 58592/58605 [============================>.] - ETA: 0s - loss: 0.6792 - accuracy: 0.7894
# Epoch 00018: val_accuracy did not improve from 0.76085
# 58605/58605 [==============================] - 26s 449us/sample - loss: 0.6792 - accuracy: 0.7894 - val_loss: 0.8223 - val_accuracy: 0.7461
# Epoch 19/30
# 58496/58605 [============================>.] - ETA: 0s - loss: 0.6626 - accuracy: 0.7952
# Epoch 00019: val_accuracy did not improve from 0.76085
# 58605/58605 [==============================] - 27s 457us/sample - loss: 0.6624 - accuracy: 0.7952 - val_loss: 0.8278 - val_accuracy: 0.7436
# Epoch 20/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.6471 - accuracy: 0.8005
# Epoch 00020: val_accuracy improved from 0.76085 to 0.77191, saving model to model-mlp/checkpoint-epoch: 20
# 58605/58605 [==============================] - 27s 459us/sample - loss: 0.6468 - accuracy: 0.8005 - val_loss: 0.7431 - val_accuracy: 0.7719
# Epoch 21/30
# 58464/58605 [============================>.] - ETA: 0s - loss: 0.6340 - accuracy: 0.8028
# Epoch 00021: val_accuracy improved from 0.77191 to 0.77307, saving model to model-mlp/checkpoint-epoch: 21
# 58605/58605 [==============================] - 27s 461us/sample - loss: 0.6336 - accuracy: 0.8030 - val_loss: 0.7402 - val_accuracy: 0.7731
# Epoch 22/30
# 58432/58605 [============================>.] - ETA: 0s - loss: 0.6231 - accuracy: 0.8071
# Epoch 00022: val_accuracy improved from 0.77307 to 0.79088, saving model to model-mlp/checkpoint-epoch: 22
# 58605/58605 [==============================] - 27s 455us/sample - loss: 0.6229 - accuracy: 0.8071 - val_loss: 0.6874 - val_accuracy: 0.7909
# Epoch 23/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.6073 - accuracy: 0.8118
# Epoch 00023: val_accuracy did not improve from 0.79088
# 58605/58605 [==============================] - 26s 445us/sample - loss: 0.6075 - accuracy: 0.8118 - val_loss: 0.7030 - val_accuracy: 0.7875
# Epoch 24/30
# 58368/58605 [============================>.] - ETA: 0s - loss: 0.5957 - accuracy: 0.8168
# Epoch 00024: val_accuracy did not improve from 0.79088
# 58605/58605 [==============================] - 26s 449us/sample - loss: 0.5959 - accuracy: 0.8166 - val_loss: 0.7524 - val_accuracy: 0.7644
# Epoch 25/30
# 58560/58605 [============================>.] - ETA: 0s - loss: 0.5839 - accuracy: 0.8182
# Epoch 00025: val_accuracy did not improve from 0.79088
# 58605/58605 [==============================] - 26s 446us/sample - loss: 0.5839 - accuracy: 0.8181 - val_loss: 0.8070 - val_accuracy: 0.7492
# Epoch 26/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.5739 - accuracy: 0.8216
# Epoch 00026: val_accuracy improved from 0.79088 to 0.79109, saving model to model-mlp/checkpoint-epoch: 26
# 58605/58605 [==============================] - 26s 451us/sample - loss: 0.5741 - accuracy: 0.8215 - val_loss: 0.6878 - val_accuracy: 0.7911
# Epoch 27/30
# 58432/58605 [============================>.] - ETA: 0s - loss: 0.5620 - accuracy: 0.8258
# Epoch 00027: val_accuracy did not improve from 0.79109
# 58605/58605 [==============================] - 27s 455us/sample - loss: 0.5625 - accuracy: 0.8256 - val_loss: 0.6923 - val_accuracy: 0.7857
# Epoch 28/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.5547 - accuracy: 0.8274
# Epoch 00028: val_accuracy improved from 0.79109 to 0.80003, saving model to model-mlp/checkpoint-epoch: 28
# 58605/58605 [==============================] - 26s 444us/sample - loss: 0.5547 - accuracy: 0.8274 - val_loss: 0.6593 - val_accuracy: 0.8000
# Epoch 29/30
# 58432/58605 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.8324
# Epoch 00029: val_accuracy did not improve from 0.80003
# 58605/58605 [==============================] - 26s 445us/sample - loss: 0.5431 - accuracy: 0.8323 - val_loss: 0.7240 - val_accuracy: 0.7765
# Epoch 30/30
# 58400/58605 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.8329
# Epoch 00030: val_accuracy improved from 0.80003 to 0.80815, saving model to model-mlp/checkpoint-epoch: 30
# 58605/58605 [==============================] - 26s 449us/sample - loss: 0.5339 - accuracy: 0.8329 - val_loss: 0.6382 - val_accuracy: 0.8081

# %%
test_result(mmodel)
# Out:
# Test Accuracy: 0.7820374965667725
# Test Loss: 0.7631333299626876

# %%
plot_model(history.history)

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
from tensorflow.keras.layers import Conv2D,MaxPool2D, BatchNormalization, Dropout

# %%
def cnn_model(input_shape, prob):
    return Sequential([
        Conv2D(32,kernel_size =3, input_shape = input_shape,activation = 'relu'),
        Conv2D(16,kernel_size = 3, activation = 'relu'),
        MaxPool2D(pool_size = 2),
        Flatten(),
        Dense(32,activation = 'relu'),
        Dropout(prob),
        Dense(32,activation = 'relu'),
        BatchNormalization(),
        Dense(10,activation = 'softmax')
        
    ])
shape = x_train_gray[0].shape
model = cnn_model(shape,0.3)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        4624
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                100384
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                330
# =================================================================
# Total params: 106,842
# Trainable params: 106,778
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
early_stop,plateau,check_path = callback('cnn')
cnn_history = model.fit(x_train_gray,y_train,epochs = 20,callbacks = [early_stop,plateau,check_path],validation_split = 0.15)
# Out:
# Train on 62268 samples, validate on 10989 samples
# Epoch 1/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 1.1398 - accuracy: 0.6271
# Epoch 00001: val_accuracy improved from -inf to 0.80608, saving model to model-cnn/checkpoint-epoch: 01
# 62268/62268 [==============================] - 531s 9ms/sample - loss: 1.1396 - accuracy: 0.6271 - val_loss: 0.6430 - val_accuracy: 0.8061
# Epoch 2/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.7771 - accuracy: 0.7542 ETA: 4s
# Epoch 00002: val_accuracy improved from 0.80608 to 0.83083, saving model to model-cnn/checkpoint-epoch: 02
# 62268/62268 [==============================] - 516s 8ms/sample - loss: 0.7771 - accuracy: 0.7542 - val_loss: 0.5726 - val_accuracy: 0.8308
# Epoch 3/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.7784
# Epoch 00003: val_accuracy improved from 0.83083 to 0.84266, saving model to model-cnn/checkpoint-epoch: 03
# 62268/62268 [==============================] - 515s 8ms/sample - loss: 0.7062 - accuracy: 0.7784 - val_loss: 0.5292 - val_accuracy: 0.8427
# Epoch 4/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.6715 - accuracy: 0.7894 ETA: 1s - loss: 0.6716 - accuracy:
# Epoch 00004: val_accuracy did not improve from 0.84266
# 62268/62268 [==============================] - 525s 8ms/sample - loss: 0.6718 - accuracy: 0.7894 - val_loss: 0.5826 - val_accuracy: 0.8251
# Epoch 5/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.6435 - accuracy: 0.7993
# Epoch 00005: val_accuracy improved from 0.84266 to 0.84730, saving model to model-cnn/checkpoint-epoch: 05
# 62268/62268 [==============================] - 523s 8ms/sample - loss: 0.6435 - accuracy: 0.7993 - val_loss: 0.5096 - val_accuracy: 0.8473
# Epoch 6/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.8038
# Epoch 00006: val_accuracy improved from 0.84730 to 0.85076, saving model to model-cnn/checkpoint-epoch: 06
# 62268/62268 [==============================] - 518s 8ms/sample - loss: 0.6298 - accuracy: 0.8038 - val_loss: 0.4973 - val_accuracy: 0.8508
# Epoch 7/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.6083 - accuracy: 0.8091
# Epoch 00007: val_accuracy improved from 0.85076 to 0.85103, saving model to model-cnn/checkpoint-epoch: 07
# 62268/62268 [==============================] - 513s 8ms/sample - loss: 0.6083 - accuracy: 0.8091 - val_loss: 0.4939 - val_accuracy: 0.8510
# Epoch 8/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5967 - accuracy: 0.8142
# Epoch 00008: val_accuracy did not improve from 0.85103
# 62268/62268 [==============================] - 516s 8ms/sample - loss: 0.5967 - accuracy: 0.8142 - val_loss: 0.4927 - val_accuracy: 0.8508
# Epoch 9/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5819 - accuracy: 0.8187
# Epoch 00009: val_accuracy improved from 0.85103 to 0.85886, saving model to model-cnn/checkpoint-epoch: 09
# 62268/62268 [==============================] - 519s 8ms/sample - loss: 0.5819 - accuracy: 0.8186 - val_loss: 0.4758 - val_accuracy: 0.8589
# Epoch 10/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5693 - accuracy: 0.8220
# Epoch 00010: val_accuracy did not improve from 0.85886
# 62268/62268 [==============================] - 519s 8ms/sample - loss: 0.5694 - accuracy: 0.8219 - val_loss: 0.4909 - val_accuracy: 0.8513
# Epoch 11/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5649 - accuracy: 0.8240
# Epoch 00011: val_accuracy did not improve from 0.85886
# 62268/62268 [==============================] - 522s 8ms/sample - loss: 0.5649 - accuracy: 0.8241 - val_loss: 0.4821 - val_accuracy: 0.8555
# Epoch 12/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5562 - accuracy: 0.8284
# Epoch 00012: val_accuracy improved from 0.85886 to 0.85931, saving model to model-cnn/checkpoint-epoch: 12
# 62268/62268 [==============================] - 523s 8ms/sample - loss: 0.5561 - accuracy: 0.8285 - val_loss: 0.4709 - val_accuracy: 0.8593
# Epoch 13/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5453 - accuracy: 0.8288
# Epoch 00013: val_accuracy improved from 0.85931 to 0.86168, saving model to model-cnn/checkpoint-epoch: 13
# 62268/62268 [==============================] - 525s 8ms/sample - loss: 0.5454 - accuracy: 0.8288 - val_loss: 0.4609 - val_accuracy: 0.8617
# Epoch 14/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5392 - accuracy: 0.8325
# Epoch 00014: val_accuracy did not improve from 0.86168
# 62268/62268 [==============================] - 528s 8ms/sample - loss: 0.5392 - accuracy: 0.8325 - val_loss: 0.4644 - val_accuracy: 0.8616
# Epoch 15/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5314 - accuracy: 0.8346
# Epoch 00015: val_accuracy did not improve from 0.86168
# 62268/62268 [==============================] - 528s 8ms/sample - loss: 0.5312 - accuracy: 0.8347 - val_loss: 0.4604 - val_accuracy: 0.8610
# Epoch 16/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5227 - accuracy: 0.8378
# Epoch 00016: val_accuracy did not improve from 0.86168
# 62268/62268 [==============================] - 520s 8ms/sample - loss: 0.5226 - accuracy: 0.8378 - val_loss: 0.4580 - val_accuracy: 0.8607
# Epoch 17/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5226 - accuracy: 0.8359
# Epoch 00017: val_accuracy did not improve from 0.86168
# 62268/62268 [==============================] - 526s 8ms/sample - loss: 0.5226 - accuracy: 0.8358 - val_loss: 0.4699 - val_accuracy: 0.8587
# Epoch 18/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5186 - accuracy: 0.8388
# Epoch 00018: val_accuracy improved from 0.86168 to 0.86869, saving model to model-cnn/checkpoint-epoch: 18
# 62268/62268 [==============================] - 530s 9ms/sample - loss: 0.5187 - accuracy: 0.8388 - val_loss: 0.4406 - val_accuracy: 0.8687
# Epoch 19/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5143 - accuracy: 0.8395
# Epoch 00019: val_accuracy did not improve from 0.86869
# 62268/62268 [==============================] - 523s 8ms/sample - loss: 0.5145 - accuracy: 0.8395 - val_loss: 0.4579 - val_accuracy: 0.8589
# Epoch 20/20
# 62240/62268 [============================>.] - ETA: 0s - loss: 0.5068 - accuracy: 0.8428
# Epoch 00020: val_accuracy did not improve from 0.86869
# 62268/62268 [==============================] - 520s 8ms/sample - loss: 0.5069 - accuracy: 0.8427 - val_loss: 0.4394 - val_accuracy: 0.8673

# %%
test_result(model)
# Out:
# Test Accuracy: 0.8482252359390259
# Test Loss: 0.49906507484298873

# %%
plot_model(cnn_history.history)

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.

# %%
def get_best_mlp(model):
    check_path = tf.train.latest_checkpoint('model-mlp')
    model.compile(optimizer = 'adam',loss = 'categorical_crossentropy', metrics = ['accuracy'])
    model.load_weights(check_path)
    return model
def get_best_cnn(model):
    check_path = tf.train.latest_checkpoint('model-cnn')
    model.compile(optimizer = 'adam',loss = 'categorical_crossentropy', metrics = ['accuracy'])
    model.load_weights(check_path)
    return model
def random_img(model):
    no_samples = x_test.shape[0]
    index=random.sample(range(1,no_samples+1),6)
    
    fig,axis = plt.subplots(1,5,figsize=(10,10))
    
    for i,ax in zip(index,axis.flatten()):
        ax.imshow(x_test[i])
        prediction = model.predict(x_test_gray[i][np.newaxis,...])
        ax.set_xlabel('prediction'+str(np.argmax(prediction)))

# %%
mlp=get_best_mlp(mlp_model(shape))
cnn=get_best_cnn(cnn_model(x_train_gray[0].shape,0.3))

# %%
print("Result of MLP model:")
test_result(mlp)
print("\nResult of CNN model:")
test_result(cnn)
# Out:
# Result of MLP model:
# Test Accuracy: 0.7820374965667725
# Test Loss: 0.7631333299626876
#
# Result of CNN model:
# Test Accuracy: 0.8498770594596863
# Test Loss: 0.5002641232012237

# %%
random_img(mlp)
